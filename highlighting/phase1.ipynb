# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import math 
import torch
import random
from transformers import AutoModelForCausalLM, AutoTokenizer

from highlight import HilightWiki, redblue
from highlight import XentLang as X

# %%
task_manager = HilightWiki()
textok, t1, t2 = task_manager.create()
hilisorted = task_manager.extract(textok, t1, t2)
# Out:
# Loading dataset shards:   0%|          | 0/41 [00:00<?, ?it/s]

# %%
# Out:
# [' Cort',
#  ' 1953',
#  'ans',
#  ' June',
#  ' (',
#  ' de',
#  'Ch',
#  '21',
#  ' F',
#  'De',
#  'z',
#  ' Food',
#  ' State',
#  ' (',
#  ' –',
#  ' moving',
#  'Political',
#  '34',
#  ' BJP',
#  'Fr',
#  'th',
#  ' state',
#  ' Consumer',
#  'an',
#  'Together',
#  ' 2',
#  ' health',
#  ' in',
#  ' politician',
#  'eren',
#  ' military',
#  ' Lok',
#  'ef',
#  ' toilets',
#  ' from',
#  ' January',
#  'ub',
#  'De',
#  ' Bhar',
#  ' 1861',
#  ' Mich',
#  'Ch',
#  ' former',
#  ' politician',
#  ' took',
#  ' representing',
#  ' Sche',
#  ' veteran',
#  'zen',
#  '78',
#  'He',
#  ' en',
#  ' represented',
#  '\n',
#  ' Ant',
#  ' Brussels',
#  ' of',
#  ' contest',
#  ' Indian',
#  ' 18',
#  '58',
#  ' father',
#  ' child',
#  ' court',
#  '.',
#  ' F',
#  ' member',
#  ' Nit',
#  ' is',
#  ' had',
#  ' Public',
#  ' He',
#  ' sch',
#  ' provided',
#  ' A',
#  'id',
#  ' Cort',
#  ' 3',
#  ' for',
#  ' (',
#  ' of',
#  ' the',
#  ' himself',
#  ' 1861',
#  ' has',
#  'ey',
#  ',',
#  ' built',
#  ' devoted',
#  ',',
#  'ada',
#  'ij',
#  ' before',
#  ' respective',
#  ' De',
#  ' those',
#  'ij',
#  ' election',
#  ' 11',
#  ' by',
#  ' his',
#  ' been',
#  ' July',
#  ' September',
#  ' a',
#  'Early',
#  '.',
#  ' stint',
#  ' for',
#  ' associated',
#  ' earlier',
#  ' Health',
#  ',',
#  'ouch',
#  ' he',
#  ' De',
#  ' "',
#  ' born',
#  ' clerk',
#  'gh',
#  ' side',
#  ' wrote',
#  ' in',
#  '-',
#  ' Mission',
#  ' in',
#  ' was',
#  ' 2021',
#  ' romantic',
#  ' clerk',
#  ' career',
#  ' given',
#  ' editor',
#  'w',
#  'sw',
#  'oga',
#  ' under',
#  ' by',
#  ' magazine',
#  'aya',
#  '.',
#  'ek',
#  ' writer',
#  ' hit',
#  ' Burns',
#  ' He',
#  ' charge',
#  ' and',
#  ' a',
#  '.',
#  ',',
#  ' was',
#  's',
#  'G',
#  'Mother',
#  ' the',
#  ' more',
#  ' such',
#  ' "',
#  ' Climate',
#  ' He',
#  ' the',
#  ' magazine',
#  '.',
#  ' from',
#  ' in',
#  '"),',
#  '.',
#  ' Distribution',
#  ' for',
#  ' to',
#  ' Nir',
#  ' published',
#  ' is',
#  ' earlier',
#  ' toilets',
#  '.',
#  ' people',
#  ' Gr',
#  ' and',
#  '.',
#  '\n',
#  ',',
#  ' and',
#  ' of',
#  ' more',
#  'li',
#  ' he',
#  '.',
#  '.',
#  ' the',
#  ' Me',
#  ' where',
#  ',',
#  ' Affairs',
#  ',',
#  ' five',
#  ' van',
#  ' to',
#  '-',
#  ',',
#  ' office',
#  ' 2012',
#  ',',
#  ' for',
#  ' the',
#  ' to',
#  ' a',
#  'an',
#  ' Joh',
#  ' was',
#  ' the',
#  ' simplicity',
#  'th',
#  ' Bit',
#  ' De',
#  ' in',
#  ' was',
#  ' To',
#  ' av',
#  ' Sabha',
#  ' the',
#  ' and',
#  ' Change',
#  ' songs',
#  'om',
#  ' caste',
#  ' and',
#  ' kind',
#  ' a',
#  ' an',
#  ' van',
#  ' Robert',
#  ' 1862',
#  ' by',
#  'ach',
#  ' Poverty',
#  ' Assembly',
#  'ar',
#  ' Bihar',
#  ' assembly',
#  ' was',
#  ' technical',
#  ' Lok',
#  'aut',
#  ' and',
#  ' was',
#  'ar',
#  'ailed',
#  '"',
#  ' the',
#  '000',
#  ' in',
#  ' was',
#  ' Sabha',
#  '.',
#  '.',
#  'th',
#  ' of',
#  ' and',
#  'in',
#  'od',
#  ',',
#  ' to',
#  'man',
#  ' ka',
#  ')',
#  ' with',
#  ' terms',
#  ' Party',
#  ',',
#  'sw',
#  'al',
#  ' Below',
#  ' R',
#  'ij',
#  ' with',
#  ' of',
#  ' to',
#  '.',
#  'p',
#  ' Line',
#  ' their',
#  ' of',
#  'ou',
#  'an',
#  ' Sabha',
#  ' editor',
#  ' as',
#  ' Modi',
#  'ati',
#  ' up',
#  'ck',
#  '-',
#  'ish',
#  'ish',
#  'in',
#  ' Sabha',
#  'ya',
#  'wer',
#  'h',
#  'ish',
#  'ata',
#  ' Bhar',
#  'at',
#  ' constituency',
#  'chief',
#  ' with',
#  ' Lok',
#  'lem',
#  'law',
#  'ing',
#  '-',
#  'ace',
#  'lem',
#  'bey',
#  ' Environment',
#  ',',
#  'lled',
#  ' of',
#  'pur',
#  'wer',
#  ' (',
#  '\n',
#  ' Kumar',
#  ' five',
#  ' Jan',
#  "'s",
#  ' R',
#  ' almost',
#  'oor',
#  ' and',
#  ' he',
#  ' minister',
#  ' State',
#  ' songs',
#  'st',
#  ' the',
#  'ag',
#  ' to',
#  'any',
#  '.',
#  ' all',
#  ' of',
#  ' to',
#  ' Tab',
#  ' Government',
#  ' to',
#  ' the',
#  'ond',
#  ' of',
#  '-',
#  ' subsidy',
#  ' and',
#  'ij',
#  '.',
#  ' a',
#  ' Jan',
#  ' J',
#  ' and',
#  ' the',
#  ' Mo',
#  ' decades',
#  ' was',
#  ' families',
#  ',',
#  ' a',
#  'p',
#  ' minister',
#  ' in',
#  ' from',
#  ' January',
#  ' is',
#  ' to',
#  'ck',
#  ' for',
#  ' h',
#  ' Legislative',
#  ' the',
#  ' illustrated',
#  ' of',
#  ' which',
#  ' was',
#  'gh',
#  ' of',
#  '.',
#  ' by',
#  ' R',
#  ')',
#  ' for',
#  ' in',
#  ' educational',
#  ' O',
#  ' in',
#  ' onwards',
#  ' and',
#  ' 18',
#  ' Hor',
#  ' El',
#  'ok',
#  ' ka',
#  ' the',
#  ' Bihar',
#  ' 18',
#  ' have',
#  '),',
#  ' Sabha',
#  ' poetry',
#  ' in',
#  ' like',
#  ' he',
#  ' and',
#  ' he',
#  ' elected',
#  ' is',
#  '.',
#  ' he',
#  'hi',
#  ' k',
#  ' 1861',
#  ' their',
#  ' home',
#  ' convinced',
#  ' health',
#  ')',
#  ' religion',
#  'oon',
#  ' B',
#  '58',
#  ' and',
#  ',',
#  'des',
#  ' career',
#  ' as',
#  'har',
#  ' and',
#  ' ',
#  ' He',
#  ' also',
#  ' an',
#  ' Ant',
#  ' from',
#  ' build',
#  ' and',
#  ' songs',
#  'V',
#  ' he',
#  ' became',
#  ' cabinet',
#  ' associated',
#  ' Narendra',
#  ' him',
#  ',',
#  ' Bihar',
#  'iya',
#  'L',
#  ' government',
#  ' of',
#  ' consecutive',
#  ' his',
#  ' 18',
#  'ans',
#  ' exce',
#  ' poet',
#  ' Sh',
#  'eder',
#  '-',
#  ' Minister',
#  'meaning',
#  ' In',
#  ' founded',
#  ' minority',
#  'ste',
#  'berg',
#  ' Lad',
#  ' shipping',
#  ' Burns',
#  '57',
#  ' of',
#  ' lied',
#  'ene',
#  ' constituency',
#  ' brought',
#  'lde',
#  ' legislative',
#  ' a',
#  ' From',
#  ' He',
#  'iel',
#  ' and',
#  'a',
#  ' (',
#  ' The',
#  ' member',
#  ' ',
#  '.',
#  ' in',
#  ' From',
#  ' Jan',
#  'oor',
#  ' journal',
#  ' Sw',
#  ' Forest',
#  ' serve',
#  ' translated',
#  'born',
#  '.',
#  ' The',
#  ' as',
#  'et',
#  ' slogan',
#  ' ',
#  ' ho',
#  ' accredited',
#  ' 17',
#  ' Bihar',
#  ' Bh',
#  ' 18',
#  'al',
#  ' Minister',
#  ' Bihar',
#  ' (',
#  ')',
#  ' He',
#  'od',
#  ' D',
#  ' 2017',
#  'han',
#  ' belonging',
#  ' resigned',
#  ' a',
#  'liberal',
#  'bey',
#  ' 16',
#  '\n',
#  'Ash',
#  ' van',
#  'ux',
#  '\n',
#  'Life',
#  'ini',
#  ' 18',
#  ' 16',
#  'On',
#  ' Jo',
#  ' Kumar',
#  'w',
#  ' Chou']

# %%
# task textification

min_y_window = int(sub_window_size)

i = random.randint(0, textok.size(-1) - min_y_window)
slice = textok[0][i:i+min_y_window]
ywidth = 3
o = slice[:ywidth]
c = slice[-ywidth:]

y = (detokenize_w(o), detokenize_w(c))
# print(y)
x1 = detokenize(t1)
x2 = detokenize(t2)

text = detokenize(textok)
func = redblue(y, x1, x2)

print(text+"\n"+func)
# Out:
# Frans Jozef de Cort (21 June 1834, in Antwerp – 18 January 1878, in Elsene), was a Flemish writer.Life
# De Cort was born and brought up in Antwerp, where he became a shipping clerk, in 1861 moving to Brussels to serve as clerk of the military court.Together with Jan Theodoor van Rijswijck he published the journal De Grondwet from 1857 to 1858. From 1858 to 1861 he was editor of the magazine De Schelde. From 1861 onwards he was editor-in-chief of De Toekomst, an illustrated educational magazine founded by his father-in-law Johan Michiel Dautzenberg. He was a convinced Flemish-liberal poet, and he wrote songs like those of Jan Theodoor van Rijswijck, and also more romantic songs, such as Moeder en kind (meaning "Mother and child"), which excelled by their simplicity.He devoted himself to the more technical side of poetry and translated songs by Robert Burns (De schoonste liederen van R. Burns, 1862) and the Odes of Horace.
# Ashwini Kumar Choubey (born 2 January 1953) is Minister of State for Consumer Affairs, Food and Public Distribution and Environment, Forest and Climate Change and a member of the 17th Lok Sabha. He is an Indian politician belonging to the Bharatiya Janata Party. He is a member of the 16th Lok Sabha representing Buxar (Lok Sabha constituency) and a former health minister of Bihar. He had represented the Bihar legislative assembly from Bhagalpur (Vidhan Sabha constituency) before contesting for the 16th Lok Sabha election.
# On 3 September 2017, he took in charge of office as Minister of State for Health in Narendra Modi's Government. He resigned in July 2021.Political career
# Choubey is a veteran politician from state of Bihar and elected to the Bihar Legislative Assembly for five consecutive terms. He was accredited to have built 11,000 toilets for minority and Below Poverty Line families under Swachh Bharat Mission.  A slogan "Ghar-ghar Me ho Shouchalaya ka Nirman, Tabhi hoga Ladli Bitiya ka kanyadaan" given by him was a hit in Bihar and people from all caste and religion availed government provided subsidy to build toilets in their respective home.Early career
# Chaubey has been associated with BJP for almost five decades and was earlier associated with Jansangh. In his earlier stint, he was the health minister in the Nitish Kumar cabinet in 2012.
# @#@#@xent_redblue~(~[ Elsene>< September 2017,]~><Frans de Cort><Ashwini Kumar Choubey)~:>:>:
